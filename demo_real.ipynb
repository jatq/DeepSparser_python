# %% [markdown]
# # DeepSparser - Real Seismic Data Demo
#
# This notebook demonstrates training and inference on real STEAD seismic data.
#
# **Prerequisites:** Run `python download_data.py` first to obtain the dataset.

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

from utils import load_config
from model.network import DeepSparser
from dataset.dataset_real import TestDataset

config = load_config('config/config_real.yaml')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {device}')
# Out:
# Device: cpu

# %% [markdown]
# ## Training
#
# Skip this cell if a trained checkpoint already exists.

# %%
from train import train
train(config)

# %% [markdown]
# ## Inference & Visualization

# %%
# Load model
model = DeepSparser(config).to(device)
model.load_state_dict(torch.load(config.checkpoint_path, map_location=device))
model.eval()

# Load test data
test_dataset = TestDataset(config)

# Visualize
indices = list(range(5))
fig, axes = plt.subplots(len(indices), 2, figsize=(14, 3 * len(indices)), tight_layout=True)

for i, idx in enumerate(indices):
    s = test_dataset[idx]
    s_hat = model.denoise(s)
    display_len = min(4001, len(s))
    
    axes[i, 0].plot(s[:display_len], lw=0.5)
    axes[i, 1].plot(s_hat[:display_len], lw=0.5)

axes[0, 0].set_title('Original (Noisy)')
axes[0, 1].set_title('Denoised')

for ax_row in axes:
    for ax in ax_row:
        ax.set_xlabel('Time (ms)')
        ax.set_ylabel('Amplitude')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 7
#       4 model.eval()
#       6 # Load test data
# ----> 7 test_dataset = TestDataset(config)
#       9 # Visualize
#      10 indices = list(range(5))
#
# File /data/workplace/projects/papers/deepsparser/DeepSparser_python/dataset/dataset_real.py:85, in TestDataset.__init__(self, config)
#      84 def __init__(self, config):
# ---> 85     super().__init__(config, is_train=False)
#
# File /data/workplace/projects/papers/deepsparser/DeepSparser_python/dataset/dataset_real.py:30, in BaseDataset.__init__(self, config, is_train)
#      28     self.n = self._normalize(self._pad(n))
#      29 else:
# ---> 30     s = load_real_data(config, is_train=False)
#      31     self.s = self._normalize(self._pad(s))
#      32     self.n = None
#
# File /data/workplace/projects/papers/deepsparser/DeepSparser_python/dataset/dataset_real.py:16, in load_real_data(config, is_train)
#      14     return signal, noise
#      15 else:
# ---> 16     signal = np.load(data_dir / "low_snr.npy")
#      17     return signal
#
# File /data/conda_envs/agent_env/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:454, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     452     own_fid = False
#     453 else:
# --> 454     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     455     own_fid = True
#     457 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/real/low_snr.npy'
